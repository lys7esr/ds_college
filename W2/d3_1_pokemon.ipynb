# %%
import pandas as pd

# %%
#load the dataset, df is data in rows and columns
df=pd.read_csv(r"D:\VS_CODE\ds_prac\data\Pokemon.csv") #r is used to consider / as input not as escape character yk
df.head() #first 5 rows
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %%
df.tail() #last 5 entries of dataset
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %%
df.sample() #random any one row
# Out:
#        #        Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 583  524  Roggenrola   Rock    NaN    280  55      75       85       25
#
#      Sp. Def  Speed  Generation  Legendary
# 583       25     15           5      False

# %%
df.sample(5) #random 5 rows,methods of pandas i.e. functions, returns computational value
# Out:
#        #       Name  Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 437  392  Infernape    Fire  Fighting    534  76     104       71      104
# 541  484     Palkia   Water    Dragon    680  90     120      100      150
# 365  334    Altaria  Dragon    Flying    490  75      70       90       70
# 461  414     Mothim     Bug    Flying    424  70      94       50       94
# 189  175     Togepi   Fairy       NaN    245  35      20       65       40
#
#      Sp. Def  Speed  Generation  Legendary
# 437       71    108           4      False
# 541      120    100           4       True
# 365      105     80           3      False
# 461       50     66           4      False
# 189       65     20           2      False

# %%
print(df.shape) #no.of rows and columns, attributes of dataframe, no computation
len(df) #no. of rows
# Out:
# (800, 13)
# 800

# %%
df.index #range of index present in data set
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
df.dtypes #data type of each column
# Out:
# #             int64
# Name            str
# Type 1          str
# Type 2          str
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# Sp. Atk       int64
# Sp. Def       int64
# Speed         int64
# Generation    int64
# Legendary      bool
# dtype: object

# %%
df.axes #info about each rows nd columns
#0-columns, 1-rows, sum of columns in a matrix #AXIS
# Out:
# [RangeIndex(start=0, stop=800, step=1),
#  Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#         'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#        dtype='str')]

# %%
df.size #total no. of elements in dataset i.e. rows and columns
# Out:
# 10400

# %%
df.ndim #dimensions are in 2 directions
# Out:
# 2

# %%
df.describe() #statistical mathematical characteristics of entire data, to find min max and other things
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.info() #no.of null values count, dtype
# less no. of null, delete the whole row
# more then fill with avg or smt
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    str
#  2   Type 1      800 non-null    str
#  3   Type 2      414 non-null    str
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), str(3)
# memory usage: 75.9 KB

# %%
sorted_df=df.sort_values(by="Attack",ascending=False) #sort the data frame by Attack column (ascending) is default
#if ascending=false then order will be descending

# %%
sorted_df
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# ..   ...                      ...      ...       ...    ...  ...     ...
# 230  213                  Shuckle      Bug      Rock    505   20      10
# 261  242                  Blissey   Normal       NaN    540  255      10
# 139  129                 Magikarp    Water       NaN    200   20      10
# 121  113                  Chansey   Normal       NaN    450  250       5
# 488  440                  Happiny   Normal       NaN    220  100       5
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# this was understanding the data, now pre-processing
# cleaning, outliers, and other important things
